# %%
import requests

# %%
tou = "Mozilla/5.0 (X11; U; Linux x86_64; zh-CN; rv:1.9.2.10) Gecko/20100922 Ubuntu/10.10 (maverick) Firefox/3.6.10"

# %%
headers = {'User-Agent': tou}

# %%
res = requests.get(r"https://ezil.me/personal_stats?wallet=0x3CBC3c9EA6fD4486c94e8Ce4Cd5E6B73A7AeC79e.zil1gjqexhafnm5ljrq5g2cdnk2gtykygmss87wkhc&coin=eth",headers = headers)

# %%
res
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup

# %%
html_str = res.text

# %%
soup = BeautifulSoup(html_str,'lxml')

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n <head nonce="cc7465d3-3d35-4bc5-b0ea-9d1acef9a624">\n  <meta content="initial-scale=1, viewport-fit=cover" name="viewport" nonce="cc7465d3-3d35-4bc5-b0ea-9d1acef9a624"/>\n  <link href="/static/apple-touch-icon.png" nonce="cc7465d3-3d35-4bc5-b0ea-9d1acef9a624" rel="apple-touch-icon" sizes="180x180"/>\n  <link href="/static/favicon-32x32.png" nonce="cc7465d3-3d35-4bc5-b0ea-9d1acef9a624" rel="icon" sizes="32x32" type="image/png"/>\n  <link href="/static/favicon-16x16.png" nonce="cc7465d3-3d35-4bc5-b0ea-9d1acef9a624" rel="icon" sizes="16x16" type="image/png"/>\n  <link href="/static/site.webmanifest" nonce="cc7465d3-3d35-4bc5-b0ea-9d1acef9a624" rel="manifest"/>\n  <link color="#5bbad5" href="/static/safari-pinned-tab.svg" nonce="cc7465d3-3d35-4bc5-b0ea-9d1acef9a624" rel="mask-icon"/>\n  <link href="/static/favicon.ico" nonce="cc7465d3-3d35-4bc5-b0ea-9d1acef9a624" rel="shortcut icon"/>\n  <meta content="#ffffff" name="msapplication-TileColor" nonce="cc
# ...

# %%
print(soup.select(".ezil-1vq6ixd e1up9sm43"))
# Out:
# []

# %%
from lxml import etree

# %%
html=etree.HTML(res.text)

# %%
result=etree.tostring(html,encoding='utf-8')

# %%
html.xpath('//*[@id="__next"]/div/div[3]/div[2]/div[2]/span/span//text()')
# Out:
# ['workers']

# %%
html.xpath('//*[@id="__next"]/div/div[3]/div[3]/div/div[1]/div[2]/span//text()')
# Out:
# []
